# %%
import json
import requests
import pandas as pd

from config import api_key_2

# %%
target_city = "Miami, United States"
#miami, las vegas, houston, pheonix 

# Build the endpoint URL
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={api_key_2}"

# %%
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'country': 'United States', 'country_code': 'us', 'state': 'Florida', 'county': 'Miami-Dade County', 'city': 'Miami', 'lon': -80.19362, 'lat': 25.7741728, 'state_code': 'FL', 'formatted': 'Miami, FL, United States of America', 'address_line1': 'Miami, FL', 'address_line2': 'United States of America', 'category': 'administrative', 'timezone': {'name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'result_type': 'city', 'rank': {'importance': 0.785448824339033, 'popularity': 7.934001693182557, 'confidence': 1, 'confidence_city_level': 1, 'match_type': 'full_match'}, 'place_id': '517ff62345640c54c059e773493030c63940f00101f9010191120000000000c00208', 'bbox': {'lo
# ...

# %%
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "query": {
#         "parsed": {
#             "city": "miami",
#             "country": "united states",
#             "expected_type": "city"
#         },
#         "text": "Miami, United States"
#     },
#     "results": [
#         {
#             "address_line1": "Miami, FL",
#             "address_line2": "United States of America",
#             "bbox": {
#                 "lat1": 25.7090517,
#                 "lat2": 25.8557827,
#                 "lon1": -80.31976,
#                 "lon2": -80.139157
#             },
#             "category": "administrative",
#             "city": "Miami",
#             "country": "United States",
#             "country_code": "us",
#             "county": "Miami-Dade County",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
# ...

# %%
latitude = 34.0536909
longitude = -118.242766

# Set the parameters for the type of place
categories = "entertainment.cinema"
#conditions = "vegetarian"
radius = 10000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    #"conditions":conditions,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":api_key_2    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
